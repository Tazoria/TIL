# %% [markdown]
# <a href="https://colab.research.google.com/github/Tazoria/TIL/blob/main/data_analysis/basic/02_DataFrame_%ED%8C%8C%EC%9D%BC%EC%9D%BD%EA%B3%A0%EC%93%B0%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 💕 여러가지 데이터파일 불러오기 / 저장하기

# %% [markdown]
# ## 💡 불러오기

# %% [markdown]
# ### 1️⃣ CSV

# %%
# header
file_path = '/content/drive/MyDrive/class/dataset/sample.csv'
# 헤더: 실제 데이터 컬럼의 시작 위치
df1= pd.read_csv(file_path, header=1)
df1
# Out:
#    1   1.15     one
# 0  2   2.23     two
# 1  3   3.34   three

# %%
# index_col
# 파일을 불러오면서 인덱스의 컬럼을 지정
df2 = pd.read_csv(file_path, index_col='c1')
df2
# Out:
#       c2      c3
# c1
# 1   1.15     one
# 2   2.23     two
# 3   3.34   three

# %% [markdown]
# ### 2️⃣ EXCEL

# %%
# 안 되면 engine='openpyxl' 속성 적용 => 근데 나는 잘된다....? => 코랩에서는 열리는 거였다... (쥬피터는 안되나 봄)
#   =>  !pip install openpyxl
df3 = pd.read_excel('/content/drive/MyDrive/class/판다스data/남북한발전전력량.xlsx')
df3.head()
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# 2  2658  2802  3196  3343  3430  3581  3427  3402  3523
# 3  1510  1478  1486  1547  1503  1388  1564  1648  1620
# 4     -     -     -     -    86   118   151   173   195
#
# [5 rows x 29 columns]

# %% [markdown]
# ### 3️⃣ JSON

# %%
df4 = pd.read_json('/content/drive/MyDrive/class/판다스data/read_json_sample.json')
df4
# Out:
#            name  year        developer opensource
# pandas           2008    Wes Mckinneye       True
# NumPy            2006  Travis Oliphant       True
# matplotlib       2003   John D. Hunter       True

# %% [markdown]
# ### 4️⃣ HTML

# %%
# 안되는 경우 !pip install lxml
df5 = pd.read_html('/content/drive/MyDrive/class/판다스data/sample.html')
print(df5)
print(len(df5)) # 해당 html 파일은 원소가 2개인 리스트로 구성
# Out:
# [   Unnamed: 0  c0  c1  c2  c3
# 0           0   0   1   4   7
# 1           1   1   2   5   8
# 2           2   2   3   6   9,          name  year        developer  opensource
# 0       NumPy  2006  Travis Oliphant        True
# 1  matplotlib  2003   John D. Hunter        True
# 2      pandas  2008    Wes Mckinneye        True]
# 2

# %%
for i in range(len(df5)):
  print('df5[%i]'%i)
  print(df5[i])
  print('\n')

df6 = df5[1]
df6.set_index(['name'], inplace=True)
print(df6)
# Out:
# df5[0]
#    Unnamed: 0  c0  c1  c2  c3
# 0           0   0   1   4   7
# 1           1   1   2   5   8
# 2           2   2   3   6   9
#
#
# df5[1]
#          name  year        developer  opensource
# 0       NumPy  2006  Travis Oliphant        True
# 1  matplotlib  2003   John D. Hunter        True
# 2      pandas  2008    Wes Mckinneye        True
#
#
#             year        developer  opensource
# name
# NumPy       2006  Travis Oliphant        True
# matplotlib  2003   John D. Hunter        True
# pandas      2008    Wes Mckinneye        True

# %% [markdown]
# ## 💡 저장하기

# %% [markdown]
# ### 1️⃣ CSV, JSON, EXCEL

# %%
# 데이터를 csv로 저장
dict_data = {'c0':[1,2,3], 'c1':[4,5,6], 'c2':[7,8,9],
             'c3':[10,11,12], 'c4':[13,14,15]}
df = pd.DataFrame(dict_data, index=['r0', 'r1', 'r2'])
df.set_index('c0', inplace=True)

df.to_csv('./df_sam_csv.csv')
df.to_json('./df_sam_json.json')
df.to_excel('./df_sam_excel.xlsx')

# %% [markdown]
# ### 2️⃣ EXCEL - Sheet 나눠서

# %%
# excel로 저장
data1 = {'c0':[1,2,3], 'c1':[4,5,6], 'c2':[7,8,9], 'c3':[10,11,12], 'c4':[13,14,15]}
df1 = pd.DataFrame(data1)
df1.set_index('c0', inplace=True)

df2 = pd.DataFrame([[15, '남', '신촌중'], [17, '여', '연세중']], index=['준서', '예은'], columns=['나이', '성별', '학교'])

writer = pd.ExcelWriter('/df_excelwriter.xlsx')
df1.to_excel(writer, sheet_name='sheet1')
df2.to_excel(writer, sheet_name='sheet2')
writer.save()

# %% [markdown]
# ## ✅ 실습 : auto-mpg.csv

# %%
# 실제 데이터 탐색(exploratory_analysis)
# header=None옵션을 줘야지 맨 위의 데이터 손실이 안됨.
car = pd.read_csv('/content/drive/MyDrive/class/판다스data/auto-mpg.csv', header=None)
car.head()
# Out:
#       0  1      2      3       4     5   6  7                          8
# 0  18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1  15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2  18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3  16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4  17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino

# %%
'''
< 피쳐 >
1) mpg: 연비
2) cylinders: 실린더 개수
3) displacement: 배기량
4) horsepower: 마력
5) weight: 무게
6) acceleration: 엔진이 초당 얻을 수 있는 가속력
7) model year: 출시 년도
8) origin: 제조 장소(1: 미국 USA, 2: 유럽 EU, 3: 일본 JPN)
9) name: 자동차 이름
'''
# 컬럼이 빠져있다! - 컬럼 지정해주기
car.columns = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
              'acceleration', 'model year', 'origin', 'name']
df = car.copy()
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# 데이터 모양 살피기
df.shape
# Out:
# (398, 9)

# %%
# 데이터셋 정보 요약
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB
# None

# %%
print(df.dtypes)
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight          float64
# acceleration    float64
# model year        int64
# origin            int64
# name             object
# dtype: object

# %%
# 데이터프레임 기술통계
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
# 데이터프레임 df의 각 열이 가지고 있는 갯수 확인 - 결측칟 제외
print(df.count())

# df.count()가 반환하는 객체 타입 출력
print(type(df.count()))
# Out:
# mpg             398
# cylinders       398
# displacement    398
# horsepower      398
# weight          398
# acceleration    398
# model year      398
# origin          398
# name            398
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
df['origin'].value_counts()
# Out:
# 1    249
# 3     79
# 2     70
# Name: origin, dtype: int64

# %%
# 평균값 - 전체
print(df.mean())


# 컬럼 1개 - mpg
# 평균
print('평균: ', df['mpg'].mean())
print('평균: ', df.mpg.mean())

# 중앙값
print('중앙값: ',  df['mpg'].median())

# 최소값
print('최소값: ', df['mpg'].min())

# 최대값
print('최대값: ', df['mpg'].max())

# 표준편차
print('표준편차: ', df['mpg'].std())
# Out:
# mpg               23.514573
# cylinders          5.454774
# displacement     193.425879
# weight          2970.424623
# acceleration      15.568090
# model year        76.010050
# origin             1.572864
# dtype: float64
# 평균:  23.514572864321607
# 평균:  23.514572864321607
# 중앙값:  23.0
# 최소값:  9.0
# 최대값:  46.6
# 표준편차:  7.815984312565782
# <ipython-input-18-a132f31a1a7a>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df.mean())

# %%
# 상관관계 구하기
corr = df[['mpg', 'weight']].corr()
print(corr)
# Out:
#              mpg    weight
# mpg     1.000000 -0.831741
# weight -0.831741  1.000000

# %% [markdown]
# ## ✅ 실습 : 남북한발전전력량.xlsx

# %%
df = df3.copy()
df.head()
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# 2  2658  2802  3196  3343  3430  3581  3427  3402  3523
# 3  1510  1478  1486  1547  1503  1388  1564  1648  1620
# 4     -     -     -     -    86   118   151   173   195
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 29 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   전력량 (억㎾h)  2 non-null      object
#  1   발전 전력별     9 non-null      object
#  2   1990       9 non-null      object
#  3   1991       9 non-null      object
#  4   1992       9 non-null      object
#  5   1993       9 non-null      object
#  6   1994       9 non-null      object
#  7   1995       9 non-null      object
#  8   1996       9 non-null      object
#  9   1997       9 non-null      object
#  10  1998       9 non-null      object
#  11  1999       9 non-null      object
#  12  2000       9 non-null      object
#  13  2001       9 non-null      object
#  14  2002       9 non-null      object
#  15  2003       9 non-null      object
#  16  2004       9 non-null      object
#  17  2005       9 non-null      object
#  18  2006       9 non-null      object
# ...

# %%
# 1990년도부터 남북 행 2개 가져오기
df_ns = df.iloc[[0, 5], 3:]
df_ns.index = ['south', 'north'] # 행 인덱스 변경
df_ns.columns = df_ns.columns.map(int) # 열 이름을 정수형으로 변경
df_ns.head()
# Out:
#        1991  1992  1993  1994  1995  1996  1997  1998  1999  2000  ...  2007  \
# south  1186  1310  1444  1650  1847  2055  2244  2153  2393  2664  ...  4031
# north   263   247   221   231   230   213   193   170   186   194  ...   236
#
#        2008  2009  2010  2011  2012  2013  2014  2015  2016
# south  4224  4336  4747  4969  5096  5171  5220  5281  5404
# north   255   235   237   211   215   221   216   190   239
#
# [2 rows x 26 columns]
