# %% [markdown]
# <a href="https://colab.research.google.com/github/Tazoria/TIL/blob/main/data_analysis/basic/02_DataFrame_%08%ED%95%A8%EC%88%98%EC%A0%81%EC%9A%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 💕 함수적용

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
titanic = sns.load_dataset('titanic')
df = titanic.loc[:, ['age', 'fare']]
df.head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %% [markdown]
# ## 1️⃣ applymap ( )

# %%
# 데이터 프레임에 연산적용(각 원소에 + 10을하는 함수)
def add_10(n):
  return n+10

df_map = df.applymap(add_10)
print(df_map.head(3))
# Out:
#     age     fare
# 0  32.0  17.2500
# 1  48.0  81.2833
# 2  36.0  17.9250

# %% [markdown]
# ## 2️⃣ apply ( )

# %%
# 결측치 찾아주는 함수
def missing_value(series):
  return series.isnull()

# %%
result = df.apply(missing_value, axis=0)
print(result.head(3))
# Out:
#      age   fare
# 0  False  False
# 1  False  False
# 2  False  False

# %%
def min_max(x):
  return x.max() - x.min()
result2 = df.apply(min_max)
print(result2)
# Out:
# age      79.5800
# fare    512.3292
# dtype: float64

# %%
df['ten'] = 10

# %%
# 데이터프레임의 2개열을 선택해서 적용
def add_two_obj(a, b):
  return a + b

df['add'] = df.apply(lambda x: add_two_obj(x['age'], x['ten']), axis=1)
df.head(3)
# Out:
#     age     fare  ten   add
# 0  22.0   7.2500   10  32.0
# 1  38.0  71.2833   10  48.0
# 2  26.0   7.9250   10  36.0

# %% [markdown]
# ## ✅ 실습 : 서울시CCTV설치운영현황(자치구)_년도별_211231기준.csv

# %%
cctv = pd.read_csv('/content/drive/MyDrive/class/판다스data/서울시CCTV설치운영현황(자치구)_년도별_211231기준.csv', skiprows=1, encoding='EUC-KR')
cctv.head()
# Out:
#     구분      총계 2012년 이전  2012년  2013년  2014년  2015년  2016년   2017년   2018년  \
# 0    계  83,557    4,812  1,851  3,434  4,295  6,840  8,708  11,572  10,627
# 1  종로구   1,715      815    NaN    NaN    195    150      0     261      85
# 2  중 구   2,447       16    114     87     77    236    240     372     386
# 3  용산구   2,611       34     71    234    125    221    298     351     125
# 4  성동구   3,829      163    144    208    107    325    255     967     415
#
#     2019년   2020년  2021년
# 0  12,267  11,247  7,904
# 1       9     200      0
# 2     155     361    403
# 3     307     617    228
# 4     490     472    283

# %%
cctv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   구분        26 non-null     object
#  1   총계        26 non-null     object
#  2   2012년 이전  26 non-null     object
#  3   2012년     25 non-null     object
#  4   2013년     25 non-null     object
#  5   2014년     26 non-null     object
#  6   2015년     26 non-null     object
#  7   2016년     26 non-null     object
#  8   2017년     26 non-null     object
#  9   2018년     26 non-null     object
#  10  2019년     26 non-null     object
#  11  2020년     26 non-null     object
#  12  2021년     26 non-null     object
# dtypes: object(13)
# memory usage: 2.8+ KB

# %%
cctv['총계'] = cctv['총계'].apply(lambda x: int(x.replace(',','')))
cctv['총계']
# Out:
# 0     83557
# 1      1715
# 2      2447
# 3      2611
# 4      3829
# 5      3211
# 6      2628
# 7      3737
# 8      4602
# 9      3090
# 10     1930
# 11     2492
# 12     4131
# 13     3055
# 14     2496
# 15     3650
# 16     2744
# 17     4608
# 18     2411
# 19     4056
# 20     2306
# 21     5149
# 22     4082
# 23     6871
# 24     2897
# 25     2809
# Name: 총계, dtype: int64

# %%
# 결측치 0으로 대체, 정수로변환

# 결측치 확인
cctv.isna().sum() # isnull()도 가능
# 대체
# cctv[['2012년', '2013년']].fillna(0, inplace=True) - 따로 해줘야 하는가봉가
cctv['2012년'].fillna('0', inplace=True)
cctv['2013년'].fillna('0', inplace=True)
cctv.isna().sum()
# Out:
# 구분          0
# 총계          0
# 2012년 이전    0
# 2012년       0
# 2013년       0
# 2014년       0
# 2015년       0
# 2016년       0
# 2017년       0
# 2018년       0
# 2019년       0
# 2020년       0
# 2021년       0
# dtype: int64

# %%
# 나머지 컬럼들의 ','도 삭제
for col in cctv.columns[2:]:
  cctv[col] = cctv[col].apply(lambda x: int(x.replace(',','')))

# %% [markdown]
# ## ✅ 실습2 : titanic
# - age :  평균으로 대체
# - embarked : 최빈값으로 대체
# - embark_town : 결측값이 있는 행 삭제

# %%
# age의 결측치를 평균으로 대체하기
df = titanic.copy()
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
mean_age = df['age'].mean().round(2)
df['age'].fillna(mean_age, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# embarked의 결측치를 최반값으로 대체
mode_embarked = df['embarked'].mode()[0]
df['embarked'].fillna(mode_embarked, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# embark_town 결측값이 있는 행 삭제
df = df.dropna(subset=['embark_town'], how='any', axis=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     889 non-null    int64
#  1   pclass       889 non-null    int64
#  2   sex          889 non-null    object
#  3   age          889 non-null    float64
#  4   sibsp        889 non-null    int64
#  5   parch        889 non-null    int64
#  6   fare         889 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        889 non-null    category
#  9   who          889 non-null    object
#  10  adult_male   889 non-null    bool
#  11  deck         201 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        889 non-null    object
#  14  alone        889 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 87.3+ KB

# %%
# deck 컬럼 삭제
df.drop('deck', inplace=True, axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     889 non-null    int64
#  1   pclass       889 non-null    int64
#  2   sex          889 non-null    object
#  3   age          889 non-null    float64
#  4   sibsp        889 non-null    int64
#  5   parch        889 non-null    int64
#  6   fare         889 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        889 non-null    category
#  9   who          889 non-null    object
#  10  adult_male   889 non-null    bool
#  11  embark_town  889 non-null    object
#  12  alive        889 non-null    object
#  13  alone        889 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 86.1+ KB

# %%
# titanic['adult/child'] 컬럼얼 만들고 20살 이상이면 adult 이하면 child로 구분
df['adult/child'] = titanic.age.apply(lambda x: 'adult' if x> 20 else 'child')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone adult/child
# 0    man        True  Southampton    no  False       adult
# 1  woman       False    Cherbourg   yes  False       adult
# 2  woman       False  Southampton   yes   True       adult
# 3  woman       False  Southampton   yes  False       adult
# 4    man        True  Southampton    no   True       adult

# %%
'''
bins = [1, 20, 30, 50, 70, 100]
label = ['미성년자', '청년', '중년', '장년', '노년']
age를 기준으로 age_cat이라는 컬럼 생성
'''
import numpy as np

count, bin_dividers = np.histogram(df['age'], bins=5)

df['age_cat'] = pd.cut(df['age'],
                       bins = [1, 20, 30, 50, 70, 100],
                       labels = ['미성년자', '청년', '중년', '장년', '노년'],
                       include_lowest=True)
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone adult/child age_cat
# 0    man        True  Southampton    no  False       adult      청년
# 1  woman       False    Cherbourg   yes  False       adult      중년
# 2  woman       False  Southampton   yes   True       adult      청년
# 3  woman       False  Southampton   yes  False       adult      중년
# 4    man        True  Southampton    no   True       adult      중년
