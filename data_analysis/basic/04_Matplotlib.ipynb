# %% [markdown]
# <a href="https://colab.research.google.com/github/Tazoria/TIL/blob/main/data_analysis/basic/04_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 💕 시각화

# %% [markdown]
# ## 💡 그래프 종류

# %% [markdown]
# ### 1️⃣ 꺾은선 그래프

# %%
# 시각화 - 꺾은선 그래프
import matplotlib.pyplot as plt
df_ns.plot()
# Out:
# <Axes: >

# %%
# 행, 열을 전치하여 다시 그리기
tdf_ns = df_ns.T
tdf_ns.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### 2️⃣ 막대 차트

# %%
# 막대차트
tdf_ns.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### 3️⃣ 산점도
# - 두 변수간의 관계를 확인 가능
#   - 양의 상관관계 : 변수 x가 증가할 때 변수 y값도 증가
#   - 음의 상관관계 : 변수 x가 증가할 때 변수 y값은 감소

# %%
# 사용 가능한 스타일 확인
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# scatter plot
df = car.copy()
plt.style.use('dark_background')
df.plot(x='weight', y='mpg', kind='scatter', c='coral', s=20, figsize=(10, 5))
plt.title('SCATTER PLOT mpg VS weight')
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# ### 4️⃣ 박스플롯
# - 데이터의 분포와 이상치를 동시에 보여주면서 다른 데이터군과의 비교도 용이
# - 다섯숫자 요약
#   - 최소값
#   - 제 1 사분위수 ( Q1 )
#   - 제 2 사분위수 ( Q2 ) : 중앙값(median)
#   - 제 3 사분위수 ( Q3 )
#   - 최대값

# %%
# 박스플롯
df[['mpg', 'cylinders']].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ## ✅ 실습 : 시도별 전출입 인구수.xlsx

# %%
population_in_out = pd.read_excel('/content/drive/MyDrive/class/판다스data/시도별 전출입 인구수.xlsx', header=0)
df = population_in_out.copy()
df.head()
# Out:
#    전출지별   전입지별      1970      1971      1972      1973      1974      1975  \
# 0  전출지별   전입지별  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1    전국     전국   4046536   4210164   3687938   4860418   5297969   9011440
# 2   NaN  서울특별시   1742813   1671705   1349333   1831858   2050392   3396662
# 3   NaN  부산광역시    448577    389797    362202    482061    680984    805979
# 4   NaN  대구광역시         -         -         -         -         -         -
#
#        1976      1977  ...      2008      2009      2010      2011      2012  \
# 0  이동자수 (명)  이동자수 (명)  ...  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1   6773250   7397623  ...   8808256   8487275   8226594   8127195   7506691
# 2   2756510   2893403  ...   2025358   1873188   1733015   1721748   1555281
# 3    724664    785117  ...    514502    519310    519334    508043    461042
# 4         -         -  ...    409938    398626    370817    370563    348642
#
#        2013      2014      2015      2016      2017
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 50 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   전출지별    19 non-null     object
#  1   전입지별    325 non-null    object
#  2   1970    325 non-null    object
#  3   1971    325 non-null    object
#  4   1972    325 non-null    object
#  5   1973    325 non-null    object
#  6   1974    325 non-null    object
#  7   1975    325 non-null    object
#  8   1976    325 non-null    object
#  9   1977    325 non-null    object
#  10  1978    325 non-null    object
#  11  1979    325 non-null    object
#  12  1980    325 non-null    object
#  13  1981    325 non-null    object
#  14  1982    325 non-null    object
#  15  1983    325 non-null    object
#  16  1984    325 non-null    object
#  17  1985    325 non-null    object
#  18  1986    325 non-null    object
#  19  1987    325 non-null    object
#  20  1988    325 non-null    object
# ...

# %%
df.describe()
# Out:
#         전출지별     전입지별 1970 1971 1972 1973 1974 1975 1976 1977  ... 2008 2009  \
# count     19      325  325  325  325  325  325  325  325  325  ...  325  325
# unique    19       19  146  146  146  146  145  146  146  146  ...  289  289
# top     전출지별  세종특별자치시    -    -    -    -    -    -    -    -  ...    -    -
# freq       1       18  180  180  180  180  180  180  180  180  ...   35   35
#
#        2010 2011  2012  2013  2014  2015  2016 2017
# count   325  325   325   325   325   325   325  325
# unique  289  291   323   320   321   324   322  323
# top       -    -  1489  1939  2026  1468  4303  947
# freq     35   35     2     2     2     2     2    2
#
# [4 rows x 50 columns]

# %%
# 누락값(NaN)을 앞 데이터로 채움
df = df.fillna(method='ffill') # ffill: forward fill
df.head()
# Out:
#    전출지별   전입지별      1970      1971      1972      1973      1974      1975  \
# 0  전출지별   전입지별  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1    전국     전국   4046536   4210164   3687938   4860418   5297969   9011440
# 2    전국  서울특별시   1742813   1671705   1349333   1831858   2050392   3396662
# 3    전국  부산광역시    448577    389797    362202    482061    680984    805979
# 4    전국  대구광역시         -         -         -         -         -         -
#
#        1976      1977  ...      2008      2009      2010      2011      2012  \
# 0  이동자수 (명)  이동자수 (명)  ...  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1   6773250   7397623  ...   8808256   8487275   8226594   8127195   7506691
# 2   2756510   2893403  ...   2025358   1873188   1733015   1721748   1555281
# 3    724664    785117  ...    514502    519310    519334    508043    461042
# 4         -         -  ...    409938    398626    370817    370563    348642
#
#        2013      2014      2015      2016      2017
# ...

# %%
# 서울에서 다른 지역으로 이동한 데이터만 추출하여 정리
mask = (df['전출지별'] == '서울특별시') & (df['전입지별'] != '서울특별시')
df_seoul = df[mask]
df_seoul = df_seoul.drop(['전출지별'], axis=1)
df_seoul.rename({'전입지별':'전입지'}, axis=1, inplace=True)
df_seoul.set_index('전입지', inplace=True)

# %%
sr_one = df_seoul.loc['경기도']

# %%
# 재설치하면 또 깨질 수 있음 - 처음에 한번만 따로 실행하기! - 그 후 런타임 재시작
import matplotlib.pyplot as plt
# 폰트깨짐 방지 - 해당 코드실행 후 반드시 런타임을 다시 시작해야 함
# 폰트설치
# !apt-get install -y fonts-nanum # 코렙에서는 한글폰트들이 한정적
# !fc-cache -fv
# !rm -rf ~/.cache/matplotlib

import matplotlib as mpl
# %matplotlib inline 
plt.rc('font', family='NanumBarunGothic')
# 마이너스 표시
mpl.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='NanumBarunGothic')


'''
[ 쥬피터 ]
from matplotlib import font_manager, rc
font_path = './malgun.ttf
font_name = font_manager.FontProperties(fname=font_path).get_name()
plt.rc('font', family='Malgun Gothic')
'''

# %%
plt.figure(figsize=(18, 12)) # 사이즈! 조절
plt.plot(sr_one.index, sr_one.values, marker='*', markersize=5) # marker: 값 표시
plt.title('서울->경기 인구 이동', size=20) # 제목
plt.xlabel('기간', size=15) # x축 이름
plt.xticks(size=12, rotation=45) # rotation: 회전각 - 수치 OR vertical 등
plt.ylabel('이동인구수', size=15) # y축 이름
plt.ylim(5000, 800000) # 축의 범위 지정(최소값, 최대값)
plt.yticks(size=12)
plt.legend(fontsize=15, labels=['서울 -> 경기'], loc='best') # 범례
# 주석 - 텍스트입력, 텍스트 위치 기준점, 텍스트 회전각, 텍스트의 상하정렬, 텍스트의 좌우정렬, 폰트사이즈
plt.annotate('인구이동증가(1970-1995)', xy=(10, 550000), rotation=25, va='baseline', ha='center', fontsize=15)
plt.annotate('인구이동감소(1995-2017)', xy=(40, 560000), rotation=335, va='baseline', ha='center', fontsize=15)
plt.show() # 변경사항을 저장하고 그래프로 출력

# %%
# 그래프 위치 지정하기
fig = plt.figure(figsize=(16,10))
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

ax1.plot(sr_one, marker='*', markersize=5)
ax2.plot(sr_one, marker='o', markersize=5, markerfacecolor='green', color='olive', linewidth=4, label='서울->경기')
ax2.legend(loc='best')
ax1.set_ylim(50000, 800000) # 좌우로 그림을 넣을거기 때문에 높이, 너비를 같게해줌
ax2.set_ylim(50000, 800000)
ax1.set_xticklabels(sr_one.index, rotation=75)
ax2.set_xticklabels(sr_one.index, rotation=75)
plt.show()
# Out:
# <ipython-input-37-1fbb9a59c73b>:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(sr_one.index, rotation=75)
# <ipython-input-37-1fbb9a59c73b>:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(sr_one.index, rotation=75)

# %%
# 서울에서 '충청남도', '경상북도', '강원도'로 이동한 인구 데이터값
col_years = list(map(str, range(1970, 2018)))
df3 = df_seoul.loc[['충청남도', '경상북도', '강원도', '전라남도'], col_years]

# %%
# 스타일 서식 지정
plt.style.use('ggplot')
fig = plt.figure(figsize=(20, 5))
ax = fig.add_subplot(1, 1, 1)
ax.plot(col_years, df3.loc['충청남도',:], marker='o', markerfacecolor='green', markersize=10, color='olive', linewidth=2, label='서울->충남')
ax.plot(col_years, df3.loc['경상북도',:], marker='o', markerfacecolor='blue', markersize=10, color='skyblue', linewidth=2, label='서울->경남')
ax.plot(col_years, df3.loc['강원도',:], marker='o', markerfacecolor='red', markersize=10, color='magenta', linewidth=2, label='서울->강원')
ax.legend(loc='best')
ax.set_title('서울 -> 충남, 경북, 강원 인구이동', size=20)
ax.set_xlabel('기간', size=12)
ax.set_ylabel('이동인구수', size=12)
ax.set_xticklabels(col_years, rotation=90)
plt.show()
# Out:
# <ipython-input-39-30d6ec0e481a>:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(col_years, rotation=90)

# %%
# df4: df3의 3개지역과 전라남도를 추가
# ax1 = sub_plot(2,2,1), ax2 = sub_plot(2,2,2) ax3=sub_plot(2,2,3)
df4 = df3.copy()

# %%
plt.style.use('ggplot')
fig = plt.figure(figsize=(40, 24))
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

ax1.plot(col_years, df3.loc['충청남도', :], marker='*', markersize=5, markerfacecolor='blue', color='aqua', linewidth=4, label='서울->충남')
ax2.plot(col_years, df3.loc['경상북도', :], marker='*', markersize=5, markerfacecolor='red', color='pink', linewidth=4, label='서울->경북')
ax3.plot(col_years, df3.loc['강원도', :], marker='*', markersize=5, markerfacecolor='orange', color='yellow', linewidth=4, label='서울->강원')
ax4.plot(col_years, df3.loc['전라남도', :], marker='*', markersize=5, markerfacecolor='green', color='olive', linewidth=4, label='서울->전남')

ax1.legend(fontsize=15)
ax2.legend(fontsize=15)
ax3.legend(fontsize=15)
ax4.legend(fontsize=15)

ax1.set_title('서울->충남 인구이동', fontsize='20')
ax2.set_title('서울->경북 인구이동', fontsize='20')
ax3.set_title('서울->강원 인구이동', fontsize='20')
ax4.set_title('서울->전남 인구이동', fontsize='20')

ax1.set_xlabel('기간', size=15)
ax2.set_xlabel('기간', size=15)
ax3.set_xlabel('기간', size=15)
ax4.set_xlabel('기간', size=15)

ax1.set_ylabel('이동 인구수', size=15)
ax2.set_ylabel('이동 인구수', size=15)
ax3.set_ylabel('이동 인구수', size=15)
ax4.set_ylabel('이동 인구수', size=15)

ax1.set_xticklabels(col_years, rotation=75)
ax2.set_xticklabels(col_years, rotation=75)
ax3.set_xticklabels(col_years, rotation=75)
ax4.set_xticklabels(col_years, rotation=75)

plt.show()
# Out:
# <ipython-input-41-d1b2194c55ae>:33: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(col_years, rotation=75)
# <ipython-input-41-d1b2194c55ae>:34: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(col_years, rotation=75)
# <ipython-input-41-d1b2194c55ae>:35: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(col_years, rotation=75)
# <ipython-input-41-d1b2194c55ae>:36: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax4.set_xticklabels(col_years, rotation=75)
# ) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 색에 핵사코드가 있음
import matplotlib
colors = {}
for name, hex in matplotlib.colors.cnames.items():
  colors[name] = hex
print(colors)
# Out:
# {'aliceblue': '#F0F8FF', 'antiquewhite': '#FAEBD7', 'aqua': '#00FFFF', 'aquamarine': '#7FFFD4', 'azure': '#F0FFFF', 'beige': '#F5F5DC', 'bisque': '#FFE4C4', 'black': '#000000', 'blanchedalmond': '#FFEBCD', 'blue': '#0000FF', 'blueviolet': '#8A2BE2', 'brown': '#A52A2A', 'burlywood': '#DEB887', 'cadetblue': '#5F9EA0', 'chartreuse': '#7FFF00', 'chocolate': '#D2691E', 'coral': '#FF7F50', 'cornflowerblue': '#6495ED', 'cornsilk': '#FFF8DC', 'crimson': '#DC143C', 'cyan': '#00FFFF', 'darkblue': '#00008B', 'darkcyan': '#008B8B', 'darkgoldenrod': '#B8860B', 'darkgray': '#A9A9A9', 'darkgreen': '#006400', 'darkgrey': '#A9A9A9', 'darkkhaki': '#BDB76B', 'darkmagenta': '#8B008B', 'darkolivegreen': '#556B2F', 'darkorange': '#FF8C00', 'darkorchid': '#9932CC', 'darkred': '#8B0000', 'darksalmon': '#E9967A', 'darkseagreen': '#8FBC8F', 'darkslateblue': '#483D8B', 'darkslategray': '#2F4F4F', 'darkslategrey': '#2F4F4F', 'darkturquoise': '#00CED1', 'darkviolet': '#9400D3', 'deeppink': '#FF1493', 'deepskyblu
# ...

# %%
df4 = df4.transpose()
df4.head()
# Out:
# 전입지    충청남도   경상북도    강원도   전라남도
# 1970  15954  11868   9352  10513
# 1971  18943  16459  12885  16755
# 1972  23406  22073  13561  20157
# 1973  27139  27531  16481  22160
# 1974  25509  26902  15479  21314

# %%
df4.index = df4.index.map(int)

# %% [markdown]
# ### 5️⃣ 면적그래프

# %%
# 면적그래프를 그리기

'''
- stacked: 그래프 누적시 그 위로 쌓는지 여부(False가 더 정확, 명확하게 표현가능)
- alpha: 투명도
'''

df4.plot(kind='area', stacked=False, alpha=0.2, figsize=(20,10))
plt.title('서울->타도시인구이동', fontsize=25)
plt.ylabel('인구이동수', size=15)
plt.xlabel('기간', size=15)
plt.legend(fontsize=15)
plt.show()

# %% [markdown]
# ### 6️⃣ 막대 그래프

# %%
# bar
df4.plot(kind='bar', figsize=(20,10), width=0.7, color=['orange', 'green', 'skyblue', 'pink'])
plt.title('서울->타도시인구이동', fontsize=25)
plt.ylabel('인구이동수', size=15)
plt.xlabel('기간', size=15)
plt.ylim(5000, 80000)
plt.legend(fontsize=15)
plt.show()

# %%
# barh
df4 = df4.T
df4['합계'] = df4.sum(axis=1)
# 합계의 가장 큰 값부터 정렬
df_total = df4[['합계']].sort_values(by='합계', ascending=True)
df_total.head()
# Out:
#              합계
# 전입지
# 경상북도  1052175.0
# 강원도   1146275.0
# 전라남도  1381657.0
# 충청남도  1529273.0

# %%
plt.style.use('ggplot')
df_total.plot(kind='barh', figsize=(10,5), width=0.7, color='cornflowerblue')
plt.title('서울->타도시인구이동', fontsize=20)
plt.ylabel('전입지')
plt.xlabel('이동인구수')
plt.show()

# %% [markdown]
# ## ✅ 실습:남북한발전전력량.xlsx

# %%
df = pd.read_excel('/content/drive/MyDrive/class/판다스data/남북한발전전력량.xlsx', convert_float=True)
df
# Out:
# <ipython-input-49-8b21eaa215e8>:1: FutureWarning: convert_float is deprecated and will be removed in a future version.
#   df = pd.read_excel('/content/drive/MyDrive/class/판다스data/남북한발전전력량.xlsx', convert_float=True)
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
# 6       NaN     수력   156   150   142   133   138   142   125   107  ...   133
# 7       NaN     화력   121   113   105    88    93    88    88    86  ...   103
# ...

# %%
# 북한 데이터만 가져오기
df = df.loc[5:9]
df.head(3)
# Out:
#   전력량 (억㎾h) 발전 전력별 1990 1991 1992 1993 1994 1995 1996 1997  ... 2007 2008  \
# 5        북한     합계  277  263  247  221  231  230  213  193  ...  236  255
# 6       NaN     수력  156  150  142  133  138  142  125  107  ...  133  141
# 7       NaN     화력  121  113  105   88   93   88   88   86  ...  103  114
#
#   2009 2010 2011 2012 2013 2014 2015 2016
# 5  235  237  211  215  221  216  190  239
# 6  125  134  132  135  139  130  100  128
# 7  110  103   79   80   82   86   90  111
#
# [3 rows x 29 columns]

# %%
df.drop('전력량 (억㎾h)', axis=1, inplace=True)
df.head()
# Out:
# <ipython-input-51-e75be6b955a2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('전력량 (억㎾h)', axis=1, inplace=True)
#   발전 전력별 1990 1991 1992 1993 1994 1995 1996 1997 1998  ... 2007 2008 2009  \
# 5     합계  277  263  247  221  231  230  213  193  170  ...  236  255  235
# 6     수력  156  150  142  133  138  142  125  107  102  ...  133  141  125
# 7     화력  121  113  105   88   93   88   88   86   68  ...  103  114  110
# 8    원자력    -    -    -    -    -    -    -    -    -  ...    -    -    -
#
#   2010 2011 2012 2013 2014 2015 2016
# 5  237  211  215  221  216  190  239
# 6  134  132  135  139  130  100  128
# 7  103   79   80   82   86   90  111
# 8    -    -    -    -    -    -    -
#
# [4 rows x 28 columns]

# %%
# 인덱스 변경
df.set_index('발전 전력별', inplace=True)
df.head()
# Out:
#        1990 1991 1992 1993 1994 1995 1996 1997 1998 1999  ... 2007 2008 2009  \
# 발전 전력별                                                    ...
# 합계      277  263  247  221  231  230  213  193  170  186  ...  236  255  235
# 수력      156  150  142  133  138  142  125  107  102  103  ...  133  141  125
# 화력      121  113  105   88   93   88   88   86   68   83  ...  103  114  110
# 원자력       -    -    -    -    -    -    -    -    -    -  ...    -    -    -
#
#        2010 2011 2012 2013 2014 2015 2016
# 발전 전력별
# 합계      237  211  215  221  216  190  239
# 수력      134  132  135  139  130  100  128
# 화력      103   79   80   82   86   90  111
# 원자력       -    -    -    -    -    -    -
#
# [4 rows x 27 columns]

# %%
# 트렌스포즈
df = df.T
df.head()
# Out:
# 발전 전력별   합계   수력   화력 원자력
# 1990    277  156  121   -
# 1991    263  150  113   -
# 1992    247  142  105   -
# 1993    221  133   88   -
# 1994    231  138   93   -

# %%
# 증감율(변동률) 계산
df = df.rename(columns={'합계':'총발전량'})
df.columns
# Out:
# Index(['총발전량', '수력', '화력', '원자력'], dtype='object', name='발전 전력별')

# %%
df['총발전량-1년'] = df['총발전량'].shift(1)
df.head()
# Out:
# 발전 전력별 총발전량   수력   화력 원자력 총발전량-1년
# 1990    277  156  121   -     NaN
# 1991    263  150  113   -     277
# 1992    247  142  105   -     263
# 1993    221  133   88   -     247
# 1994    231  138   93   -     221

# %%
# 파생변수(증감율) 만들기
df['증감율'] = ((df['총발전량'] / df['총발전량-1년'])-1)*100
df.head()
# Out:
# 발전 전력별 총발전량   수력   화력 원자력 총발전량-1년        증감율
# 1990    277  156  121   -     NaN        NaN
# 1991    263  150  113   -     277  -5.054152
# 1992    247  142  105   -     263   -6.08365
# 1993    221  133   88   -     247 -10.526316
# 1994    231  138   93   -     221   4.524887

# %% [markdown]
# ### 7️⃣ 2축 그래프

# %%
# 2축 그래프 그리기
ax1 = df[['수력', '화력']].plot(kind='bar', figsize=(20,10), width=0.7, stacked=True)
ax2 = ax1.twinx() # x축은 공유하고 y축만 다름
ax2.plot(df.index, df.증감율,
         ls='--', marker='o', markersize=20, color='green', label='전년대비 증감율(%)') # ls: Line Style
ax1.set_ylim(0, 500)
ax2.set_ylim(-50, 50)
ax1.set_xlabel('연도', size=20)
ax1.set_ylabel('발전량(억 Kwh)')
ax2.set_ylabel('전년대비 증감율')
plt.title('북한 전력 발전량(1990~2016)', size=25)
ax1.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 8️⃣ 히스토그램
# - 단변수 데이터의 빈도수

# %%
# histogram
df = car.copy()
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# 연비(mpg) 열에 대한 히스토그램을 그리기
# bins: mpg(10~50 의 정의값)을 10구간으로 나눔
plt.style.use('classic')
df['mpg'].plot(kind='hist', bins=10, color='coral', figsize=(10,5))
# 그래프 꾸미기
plt.title('HISTOGRAM')
plt.xlabel('mpg')
plt.show()

# %% [markdown]
# ### 9️⃣ 버블차트
# - 산점도의 한 종류
# - x축, y축을 포함해 크기수치도 적용 가능

# %%
# bubble chart 1
plt.style.use('bmh')

# 버블차트를 그리기 위해 cylinders 개수의 상대적 비율을 계산하여 시리즈 생성
cylinder_size = df.cylinders / df.cylinders.max() * 300
df.plot(x='weight', y='mpg', kind='scatter', c='coral', s=cylinder_size, figsize=(10,5), alpha=0.3)
plt.title('SCATTER PLOT: mpg-weight-cylinders')
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
# bubble chart 2: 3개의 변수로 산점도 그리기
plt.style.use('dark_background')
# cmap: color map
df.plot(x='weight', y='mpg', kind='scatter', c=cylinder_size, s=100, figsize=(10,5), alpha=0.3, cmap='cool', marker='*')
plt.title('SCATTER PLOT: mpg-weight-cylinders')
plt.show()

# %% [markdown]
# ### 🔟 파이 차트

# %%
# pie chart

df['count'] = 1
df_origin = df.groupby('origin').sum()
print(df_origin)
# Out:
#            mpg  cylinders  displacement    weight  acceleration  model year  \
# origin
# 1       5000.8       1556       61229.5  837121.0        3743.4       18827
# 2       1952.4        291        7640.0  169631.0        1175.1        5307
# 3       2405.6        324        8114.0  175477.0        1277.6        6118
#
#         count
# origin
# 1         249
# 2          70
# 3          79

# %%
df_origin.index = ['USA', 'EU', 'JAPAN']
# autopct: 자동으로 비율값 구해줌
# startangle: 파이 조각을 나누는 시작점(각도표시)
df_origin['count'].plot(kind='pie', figsize=(7,5), autopct='%1.1f%%', startangle=10, colors=['chocolate', 'bisque', 'cadetblue'])
plt.title('Model origin', size=20)
plt.axis('equal') # 파이차트의 비율을 원에 가깝게 조정
plt.legend(labels=df_origin.index, loc='upper right')
plt.show()

# %%
# box plot

# 그래프의 객체를 생성(fig에 2개의 서브 플롯을 생성)
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)
# ax 객체에 boxplot 메서드로 그래프 출력
ax1.boxplot(x=[df[df['origin'] == 1]['mpg'],
               df[df['origin'] == 2]['mpg'],
               df[df['origin']==3]['mpg']], labels=['USA', 'EU', 'JAPAN'])
ax2.boxplot(x=[df[df['origin'] == 1]['mpg'],
               df[df['origin'] == 2]['mpg'],
               # vert=False: 박스플롯을 옆으로 그리기
               df[df['origin']==3]['mpg']], labels=['USA', 'EU', 'JAPAN'], vert=False)
ax1.set_title('제조국가별 연비분포(수직박스)')
ax2.set_title('제조국가별 연비분포(수평박스)')
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 51312 (\N{HANGUL SYLLABLE JO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
