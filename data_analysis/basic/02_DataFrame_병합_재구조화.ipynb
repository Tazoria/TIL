# %% [markdown]
# <a href="https://colab.research.google.com/github/Tazoria/TIL/blob/main/data_analysis/basic/02_DataFrame_%EB%B3%91%ED%95%A9_%EC%9E%AC%EA%B5%AC%EC%A1%B0%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # ⭐️💕 데이터프레임 병합

# %% [markdown]
# ## 💡 concat
# - pd.concat( 데이터프레임 리스트, aixs=축 )

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### 1️⃣ 행으로 연결하기

# %%
# pd.concat
df1 = pd.DataFrame([['a', 1], ['b', 2]], columns=['letter', 'number'])
df2 = pd.DataFrame([['c', 3], ['d', 4]], columns=['letter', 'number'])
df3 = pd.DataFrame([['w', 5, '!'], ['f', 6, '@']], columns=['letter', 'number', 'etc'])

print('[df1]\n', df1, '\n')
print('[df2]\n', df2, '\n')
print('[df3]\n', df3, '\n')
# Out:
# [df1]
#    letter  number
# 0      a       1
# 1      b       2
#
# [df2]
#    letter  number
# 0      c       3
# 1      d       4
#
# [df3]
#    letter  number etc
# 0      w       5   !
# 1      f       6   @

# %%
# 컬럼명 기준으로 연결
df_rowconcat = pd.concat([df1, df2, df3])
df_rowconcat
# Out:
#   letter  number  etc
# 0      a       1  NaN
# 1      b       2  NaN
# 0      c       3  NaN
# 1      d       4  NaN
# 0      w       5    !
# 1      f       6    @

# %%
# 공통된 컬럼만 남기기
df_rowconcat2 = pd.concat([df1,df2,df3], join='inner')
df_rowconcat2
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 0      c       3
# 1      d       4
# 0      w       5
# 1      f       6

# %%
# 인덱스 재지정
df_rowconcat3 = pd.concat([df1, df2, df3], join='inner', ignore_index=True)
df_rowconcat3
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 2      c       3
# 3      d       4
# 4      w       5
# 5      f       6

# %% [markdown]
# ### 2️⃣ 열로 연결하기

# %%
df4 = pd.DataFrame({'age':[20,21,22]}, index=['amy','james','david'])
df5 = pd.DataFrame({'phone':['010-1111-1111', '010-2222-2222', '010-3333-3333']}, index=['amy','james','david'])
df6 = pd.DataFrame({'job':['studnet','programer','ceo','designer']}, index=['amy','james','david','kim'])

print('[df4]\n', df4, '\n')
print('[df5]\n', df5, '\n')
print('[df6]\n', df6, '\n') # kim 한 마리 추가
# Out:
# [df4]
#         age
# amy     20
# james   21
# david   22
#
# [df5]
#                 phone
# amy    010-1111-1111
# james  010-2222-2222
# david  010-3333-3333
#
# [df6]
#               job
# amy      studnet
# james  programer
# david        ceo
# kim     designer

# %%
# 별다른 옵션 없이 붙이기 : 모든 컬럼을 다 포함(해당 컬럼이 없는 경우 NaN값), axis=0방향으로 이어붙임
df_column_concat = pd.concat([df4,df5,df6])
df_column_concat
# Out:
#         age          phone        job
# amy    20.0            NaN        NaN
# james  21.0            NaN        NaN
# david  22.0            NaN        NaN
# amy     NaN  010-1111-1111        NaN
# james   NaN  010-2222-2222        NaN
# david   NaN  010-3333-3333        NaN
# amy     NaN            NaN    studnet
# james   NaN            NaN  programer
# david   NaN            NaN        ceo
# kim     NaN            NaN   designer

# %%
# joiun='inner': 해당 데이터에 공통된 부분만 병합
# axis=1: 컬럼방향 병합
df_column_concat2 = pd.concat([df4,df5,df6], join='inner', axis=1)
df_column_concat2
# Out:
#        age          phone        job
# amy     20  010-1111-1111    studnet
# james   21  010-2222-2222  programer
# david   22  010-3333-3333        ceo

# %% [markdown]
# ## 💡 merge
# - pd.merge( left, right, on = 기준컬럼, how = 연결방법 )

# %%
df = pd.read_csv('/content/drive/MyDrive/class/판다스실습/scores.csv')
df.head(3)
# Out:
#       name    kor    eng   math
# 0    Aiden  100.0   90.0   95.0
# 1  Charles   90.0   80.0   75.0
# 2   Danial   95.0  100.0  100.0

# %%
df7 = df.loc[[1,2,3]][['name', 'eng']]
df8 = df.loc[[1,2,4]][['name', 'math']]

print('[df7]\n', df7, '\n')
print('[df8]\n', df8, '\n')
# Out:
# [df7]
#        name    eng
# 1  Charles   80.0
# 2   Danial  100.0
# 3     Evan  100.0
#
# [df8]
#        name   math
# 1  Charles   75.0
# 2   Danial  100.0
# 4    Henry   60.0

# %%
# 공통 데이터만으로 연결
pd.merge(df7, df8, on='name') # default: how='inner'
# Out:
#       name    eng   math
# 0  Charles   80.0   75.0
# 1   Danial  100.0  100.0

# %%
pd.merge(df7, df8, on='name', how='outer')
# Out:
#       name    eng   math
# 0  Charles   80.0   75.0
# 1   Danial  100.0  100.0
# 2     Evan  100.0    NaN
# 3    Henry    NaN   60.0

# %%
# how='left': 왼쪽 프레임을 기준으로 오른쪽 프레임을 병합(오른쪽에만 있는 경우는 짤림)
pd.merge(df7, df8, on='name', how='left')
# Out:
#       name    eng   math
# 0  Charles   80.0   75.0
# 1   Danial  100.0  100.0
# 2     Evan  100.0    NaN

# %%
# how='right': 오른쪽 프레임을 기준으로 왼쪽 프레임을 병합(왼쪽에만 있는 경우는 짤림)
pd.merge(df7, df8, on='name', how='right')
# Out:
#       name    eng   math
# 0  Charles   80.0   75.0
# 1   Danial  100.0  100.0
# 2    Henry    NaN   60.0

# %% [markdown]
# # 💕 재구조화

# %% [markdown]
# ## 💡 행과 열의 형태 변형

# %% [markdown]
# ### 1️⃣ melt
# - 가로 데이터 -> 세로 데이터
# - unpivot
# - 방법1 : df.melt( )
# - 방법2 : pd.melt( df )

# %%
df.head()
# Out:
#       name    kor    eng   math
# 0    Aiden  100.0   90.0   95.0
# 1  Charles   90.0   80.0   75.0
# 2   Danial   95.0  100.0  100.0
# 3     Evan  100.0  100.0  100.0
# 4    Henry    NaN   35.0   60.0

# %%
# melt
df.melt()
# Out:
#     variable    value
# 0       name    Aiden
# 1       name  Charles
# 2       name   Danial
# 3       name     Evan
# 4       name    Henry
# ..       ...      ...
# 115     math     95.0
# 116     math    100.0
# 117     math    100.0
# 118     math     70.0
# 119     math     95.0
#
# [120 rows x 2 columns]

# %%
# 고정할 컬럼을 지정하여 melt: id_vars = 열이름 | [열이름리스트]

# name을 고정
df.melt(id_vars='name').head(10)
# Out:
#       name variable  value
# 0    Aiden      kor  100.0
# 1  Charles      kor   90.0
# 2   Danial      kor   95.0
# 3     Evan      kor  100.0
# 4    Henry      kor    NaN
# 5      Ian      kor   90.0
# 6    James      kor   70.0
# 7   Julian      kor   80.0
# 8   Justin      kor   50.0
# 9    Kevin      kor  100.0

# %%
# name, kor 고정
df.melt(id_vars=['name', 'kor']).head(10)
# Out:
#       name    kor variable  value
# 0    Aiden  100.0      eng   90.0
# 1  Charles   90.0      eng   80.0
# 2   Danial   95.0      eng  100.0
# 3     Evan  100.0      eng  100.0
# 4    Henry    NaN      eng   35.0
# 5      Ian   90.0      eng  100.0
# 6    James   70.0      eng   75.0
# 7   Julian   80.0      eng   90.0
# 8   Justin   50.0      eng   60.0
# 9    Kevin  100.0      eng  100.0

# %%
# 행으로 위치를 변경할 열 지정
# 'value_vars=열이름 | [열이름리스트]
df.melt(id_vars='name', value_vars='kor').head(10)
# Out:
#       name variable  value
# 0    Aiden      kor  100.0
# 1  Charles      kor   90.0
# 2   Danial      kor   95.0
# 3     Evan      kor  100.0
# 4    Henry      kor    NaN
# 5      Ian      kor   90.0
# 6    James      kor   70.0
# 7   Julian      kor   80.0
# 8   Justin      kor   50.0
# 9    Kevin      kor  100.0

# %%
df.melt(id_vars='name', value_vars=['kor', 'eng']).head(10)
# Out:
#       name variable  value
# 0    Aiden      kor  100.0
# 1  Charles      kor   90.0
# 2   Danial      kor   95.0
# 3     Evan      kor  100.0
# 4    Henry      kor    NaN
# 5      Ian      kor   90.0
# 6    James      kor   70.0
# 7   Julian      kor   80.0
# 8   Justin      kor   50.0
# 9    Kevin      kor  100.0

# %%
df.melt(id_vars='name', value_vars=['kor','eng'],
        var_name='subject', value_name='score').head(10)
# Out:
#       name subject  score
# 0    Aiden     kor  100.0
# 1  Charles     kor   90.0
# 2   Danial     kor   95.0
# 3     Evan     kor  100.0
# 4    Henry     kor    NaN
# 5      Ian     kor   90.0
# 6    James     kor   70.0
# 7   Julian     kor   80.0
# 8   Justin     kor   50.0
# 9    Kevin     kor  100.0

# %% [markdown]
# ## 💡 열을 행으로 보내기

# %% [markdown]
# ### 1️⃣ pivot
# - 데이터프레임.pivot(index = 인덱스로 사용할 컬럼, columns=컬럼으로 사용할 컬럼, values=값으로 사용할 컬럼)

# %%
df = df.melt(id_vars='name', var_name='subject',
             value_name='score')
df.head(10)
# Out:
#       name subject  score
# 0    Aiden     kor  100.0
# 1  Charles     kor   90.0
# 2   Danial     kor   95.0
# 3     Evan     kor  100.0
# 4    Henry     kor    NaN
# 5      Ian     kor   90.0
# 6    James     kor   70.0
# 7   Julian     kor   80.0
# 8   Justin     kor   50.0
# 9    Kevin     kor  100.0

# %%
def get_grade(x):
  if x >= 90:
    grade = 'A'
  elif x >= 80:
    grade = 'B'
  elif x >= 70:
    grade = 'C'
  elif x >= 60:
    grade = 'D'
  else:
    grade = 'F'
  return grade

# %%
df['grade'] = df['score'].apply(get_grade)
df = df.sort_values('name')
df.head(10)
# Out:
#        name subject  score grade
# 0     Aiden     kor  100.0     A
# 60    Aiden    math   95.0     A
# 30    Aiden     eng   90.0     A
# 73      Amy    math   90.0     A
# 43      Amy     eng   75.0     C
# 13      Amy     kor   90.0     A
# 1   Charles     kor   90.0     A
# 61  Charles    math   75.0     C
# 31  Charles     eng   80.0     B
# 74    Chloe    math   95.0     A

# %%
# pivot
df.pivot(index='name', columns='subject', values='score').head(10)
# Out:
# subject    eng    kor   math
# name
# Aiden     90.0  100.0   95.0
# Amy       75.0   90.0   90.0
# Charles   80.0   90.0   75.0
# Chloe    100.0   95.0   95.0
# Danial   100.0   95.0  100.0
# Danna    100.0  100.0  100.0
# Ellen     60.0    NaN    NaN
# Emma      65.0   70.0   70.0
# Evan     100.0  100.0  100.0
# Henry     35.0    NaN   60.0

# %%
df.pivot(index='name', columns='subject', values='grade').head(10)
# Out:
# subject eng kor math
# name
# Aiden     A   A    A
# Amy       C   A    A
# Charles   B   A    C
# Chloe     A   A    A
# Danial    A   A    A
# Danna     A   A    A
# Ellen     D   F    F
# Emma      D   C    C
# Evan      A   A    A
# Henry     F   F    D

# %%
df.pivot(index='name', columns='subject', values=['score', 'grade']).head(10)
# Out:
#          score               grade
# subject    eng    kor   math   eng kor math
# name
# Aiden     90.0  100.0   95.0     A   A    A
# Amy       75.0   90.0   90.0     C   A    A
# Charles   80.0   90.0   75.0     B   A    C
# Chloe    100.0   95.0   95.0     A   A    A
# Danial   100.0   95.0  100.0     A   A    A
# Danna    100.0  100.0  100.0     A   A    A
# Ellen     60.0    NaN    NaN     D   F    F
# Emma      65.0   70.0   70.0     D   C    C
# Evan     100.0  100.0  100.0     A   A    A
# Henry     35.0    NaN   60.0     F   F    D

# %%
df.transpose()
# Out:
#             0      60     30    73    43    13       1        61       31  \
# name     Aiden  Aiden  Aiden   Amy   Amy   Amy  Charles  Charles  Charles
# subject    kor   math    eng  math   eng   kor      kor     math      eng
# score    100.0   95.0   90.0  90.0  75.0  90.0     90.0     75.0     80.0
# grade        A      A      A     A     C     A        A        C        B
#
#             74  ...      27       26       56       86      58      28  \
# name     Chloe  ...  Vikkie  Viviana  Viviana  Viviana  Winnie  Winnie
# subject   math  ...     kor      kor      eng     math     eng     kor
# score     95.0  ...     NaN    100.0     80.0    100.0   100.0    70.0
# grade        A  ...       F        A        B        A       A       C
#
#              88    29    59    89
# name     Winnie  Zuly  Zuly  Zuly
# subject    math   kor   eng  math
# score      70.0  80.0  90.0  95.0
# grade         C     B     A     A
#
# [4 rows x 90 columns]
